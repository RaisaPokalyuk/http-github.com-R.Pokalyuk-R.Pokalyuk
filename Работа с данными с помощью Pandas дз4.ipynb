# %% [markdown]
# Будем работать с датасетом Pima Indian Diabetes - это набор данных из Национального института диабета, болезней органов пищеварения и почек. Целью набора данных является диагностическое прогнозирование наличия диабета у пациента. Несколько ограничений были наложены на выбор этих экземпляров из большой базы данных. В частности, все пациенты здесь - женщины в возрасте от 21 года, индийского происхождения.

# %% [markdown]
# Описание данных:Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, Age
#
# - __Pregnancies__ - данная единица отображает количество беременностей, единицы измерения - целые числа от 0 до N. Тип переменной - количественная, дискретная.
# - __Glucose__ - данная единица отображает уровень глюкозы в крови, единицы измерения - целые числа. Тип переменной - количественная, дискретная.
# - __BloodPressure__ - данная единица отображает артериальное давление, единицы измерения - миллиметры р/с, целые числа. Тип переменной - количественная, дискретная.
# - __SkinThickness__ - данная единица отображает обхват трицепса в миллиметрах, целые числа. Тип переменной - количественная, дискретная.
# - __Insulin__ - данная единица отображает уровень инсулина в крови, целые числа. Тип переменной - количественная, дискретная.
# - __BMI__ - данная единица отображает индекс массы тела. Тип переменной - количественная, непрерывная.
# - __DiabetesPedigreeFunction__ - данная единица отображает риск наследственного диабета в зависимости наличия диабета у родственников. Выражается десятичной дробью от 0 до 1. Тип переменной - количественная, непрерывная.
# - __Age__ - данная единица отражает возраст в целых числах. Тип переменной - количественная, дискретная.
# - __Class__ - данная единица отражает наличие диабета у субъекта, выражена 0(здоров) или 1(болен). Тип переменной - категориальная, бинарная.

# %%
# Подключение библиотек
import pandas as pd
import numpy as np
import math

# %% [markdown]
# **Задание 1.** Загрузите и ознакомьтесь с полученным набором данных.

# %%
# Ваш код здесь
df = pd.read_csv('/content/07.06.24+diabet.csv')
df.head(3)
#type(df)
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
#
#    diabetespedigreefunction  age  class
# 0                     0.627   50      1
# 1                     0.351   31      0
# 2                     0.672   32      1

# %% [markdown]
# **Задание 2.** Вычислите основные статистики (минимум, максимум, среднее, дисперсию) для всех столбцов.

# %%
# Ваш код здесь
df.min()
# Out:
# pregnancies                  0.000
# glucose                     44.000
# bloodpressure               24.000
# skinthickness                7.000
# insulin                     14.000
# bmi                         18.200
# diabetespedigreefunction     0.078
# age                         21.000
# class                        0.000
# dtype: float64

# %%
df.max()
# Out:
# pregnancies                  17.00
# glucose                     199.00
# bloodpressure               122.00
# skinthickness                99.00
# insulin                     846.00
# bmi                          67.10
# diabetespedigreefunction      2.42
# age                          81.00
# class                         1.00
# dtype: float64

# %%
df.mean()
# Out:
# pregnancies                   3.845052
# glucose                     121.656250
# bloodpressure                72.386719
# skinthickness                29.108073
# insulin                     140.671875
# bmi                          32.457464
# diabetespedigreefunction      0.471876
# age                          33.240885
# class                         0.348958
# dtype: float64

# %%
df.var()
# Out:
# pregnancies                   11.354056
# glucose                      926.489244
# bloodpressure                146.328741
# skinthickness                 77.285567
# insulin                     7462.033002
# bmi                           47.267706
# diabetespedigreefunction       0.109779
# age                          138.303046
# class                          0.227483
# dtype: float64

# %% [markdown]
# **Задание 3.** У скольких женщин старше 50 лет обнаружен диабет?

# %%
# Ваш код здесь
df.head(5)
df[(df['age']>50)&(df['class']==1)]
df[(df['age']>50)&(df['class']==1)].shape[0]
# Out:
# 38

# %% [markdown]
# **Задание 4.** Найдите трех женщин с наибольшим числом беременностей.

# %%
# Ваш код здесь
df.nlargest(3,'pregnancies')
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 159           17    163.0           72.0           41.0    114.0  40.9
# 88            15    136.0           70.0           32.0    110.0  37.1
# 298           14    100.0           78.0           25.0    184.0  36.6
#
#      diabetespedigreefunction  age  class
# 159                     0.817   47      1
# 88                      0.153   43      1
# 298                     0.412   46      1

# %% [markdown]
# **Задание 5.** Сколько женщин возраста между 30 и 40 успело родить 3 или более детей?

# %%
# Ваш код здесь
df[(df.age.between(30,40))&(df['pregnancies']>=3)].shape[0]
# Out:
# 142

# %% [markdown]
# **Задание 6.** Нормальным кровяным давлением будем считать давление в диапазоне [80-89]. У какого процента женщин давление нормальное?

# %%
# Ваш код здесь
cnt_all=df.shape[0] #общее количество женщин
cnt_norm=df.bloodpressure.between(80,89).sum() #количество женщин с нормальным кровяным давлением
print(f'Процент {cnt_norm/cnt_all*100:.2f}%')
# Out:
# Процент 18.88%

# %% [markdown]
# **Задание 7.** Считается, что BMI >= 30 - это признак ожирения.
# У скольких женщин с признаками ожирения кровяное давление выше среднего?

# %%
# Ваш код здесь
df[(df.bmi>=30)&(df.bloodpressure>89)].shape[0]
# Out:
# 45

# %% [markdown]
# **Задание 8.** Сравните средние значения для признаков __Glucose,	BloodPressure,	Insulin__ среди тех, у кого обнаружен диабет, и тех, у кого его нет.

# %%
# Ваш код здесь
df.head(5)
df2=df.groupby(['class'])[['glucose','bloodpressure','insulin']].agg(['mean'])
df2.columns=['glucose mean','bloodpressure mean','insulin mean']
print(df2)
# Out:
#        glucose mean  bloodpressure mean  insulin mean
# class
# 0        110.682000           70.920000    127.792000
# 1        142.130597           75.123134    164.701493

# %% [markdown]
# **Задание 9.** Добавьте новый бинарный признак:
#
# __wasPregnant__ $\in$ {0,1} - была женщина беременна (1) или нет (0)

# %%
# Ваш код здесь
def get_pregnancies(cnt_pregnancies:int) -> int:
    "здесь cnt_pregnancies -- параметр, соответствующий количеству беременностей"

    # если количество беременностей больше 0, то 1, иначе 0
    if cnt_pregnancies > 0:
        return 1
    else:
        return 0

df['wasP'] = df.pregnancies.apply(get_pregnancies)
df[['pregnancies','wasP']]
# Out:
#      pregnancies  wasP
# 0              6     1
# 1              1     1
# 2              8     1
# 3              1     1
# 4              0     0
# ..           ...   ...
# 763           10     1
# 764            2     1
# 765            5     1
# 766            1     1
# 767            1     1
#
# [768 rows x 2 columns]

# %% [markdown]
# **Задание 10.** Сравните процент больных диабетом среди женщин, которые были беременны и не были.

# %%
# Ваш код здесь
df[df.pregnancies>0].shape[0] #количество беременных женщин
df[(df.pregnancies>0)& (df['class']==1)].shape[0] #количество больных среди беременных женщин
df[(df.pregnancies>0)& (df['class']==1)].shape[0]/df[df.pregnancies>0].shape[0]
# Out:
# 0.350076103500761

# %%
df[df.pregnancies==0].shape[0] #количество небеременных женщин
df[(df.pregnancies==0)& (df['class']==1)].shape[0] #количество больных среди небеременных женщин
df[(df.pregnancies==0)& (df['class']==1)].shape[0]/df[df.pregnancies==0].shape[0]
# Out:
# 0.34234234234234234

# %% [markdown]
# **Задание 11.** Добавьте новый категориальный признак __bodyType__ на основе столбца BMI:
#
# __BMI Categories:__
#
# Underweight = <18.5
#
# Normal weight = 18.5–24.9
#
# Overweight = 25–29.9
#
# Obesity = BMI of 30 or greater
#
# Признак должен принимать значения Underweight, Normal weight, Overweight и Obesity.

# %%
# Ваш код здесь
def get_category_bmi(value_bmi:float)->float: #пишем на вход BMI
    if value_bmi<=18.5:
      return 'Underweight'
    elif (value_bmi<=18.5)&(value_bmi<=24.9):
      return 'Normal weight'
    elif (value_bmi>=25)&(value_bmi<=29.9):
      return 'Overweigh'
    else:
      return 'Obesity'

df['bmi_categories']=df['bmi'].apply(get_category_bmi)

df.head(10)
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin        bmi  \
# 0            6    148.0           72.0           35.0    125.0  33.600000
# 1            1     85.0           66.0           29.0    125.0  26.600000
# 2            8    183.0           64.0           29.0    125.0  23.300000
# 3            1     89.0           66.0           23.0     94.0  28.100000
# 4            0    137.0           40.0           35.0    168.0  43.100000
# 5            5    116.0           74.0           29.0    125.0  25.600000
# 6            3     78.0           50.0           32.0     88.0  31.000000
# 7           10    115.0           72.0           29.0    125.0  35.300000
# 8            2    197.0           70.0           45.0    543.0  30.500000
# 9            8    125.0           96.0           29.0    125.0  32.457464
#
#    diabetespedigreefunction  age  class  wasP bmi_categories
# 0                     0.627   50      1     1        Obesity
# ...

# %% [markdown]
# **Задание 12.** Будем считать "здоровыми" тех, у кого нормальный вес и кровяное давление. Какой процент "здоровых" женщин больны диабетом?

# %%
# Ваш код здесь
healthy=df[(df['bmi']>=18.5)&(df['bmi']<=24.9)\
        &(df['bloodpressure']>=80)\
        &(df['bloodpressure']<=89)]
percent_healthy_diabetic=(len(healthy[healthy['class']==1])/len(healthy))*100
print(f'''процент "здоровых" женщин больны диабетом:{percent_healthy_diabetic}%''')
# Out:
# процент "здоровых" женщин больны диабетом:10.0%
